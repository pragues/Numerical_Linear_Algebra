# %% [markdown]
# Determinant of matrix $A$ represents the "volume" of the "stuff" spanned by its column vectors.
#
# $A \in \mathbb{R}^{2 \times 2}$: area
#
# $A \in \mathbb{R}^{3 \times 3}$: volume
