# %% [markdown]
# ### Random Rotation
#
# Hadamard Rotation说的就是你！
#
# 相关的有趣的reference:
#
# intro and overview：https://zhuanlan.zhihu.com/p/1971155871955399081
#
# 古早random projection视角：https://proceedings.neurips.cc/paper/2019/file/a32d7eeaae19821fd9ce317f3ce952a7-Paper.pdf
#
# ANN quantization: https://github.com/gaoj0017/RaBitQ
